# %%
# !pip install pennylane
# !pip install noisyopt
# !pip install ipympl
# !pip install ibm_quantum_widgets
# Out:
# Requirement already satisfied: pennylane in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (0.27.0)
# Requirement already satisfied: appdirs in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (2.10.0)
# Requirement already satisfied: requests in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (2.28.1)
# Requirement already satisfied: cachetools in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (5.2.0)
# Requirement already satisfied: networkx in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (2.8.8)
# Requirement already satisfied: autoray>=0.3.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (0.5.2)
# Requirement already satisfied: retworkx in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (0.12.0)
# Requirement already satisfied: autograd in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (1.5)
# Requirement already satisfied: toml in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: numpy in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (1.23.1)
# Requirement already satisfied: pennylane-lightning>=0.27 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (0.27.0)
# Requirement already satisfied: scipy in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane) (1.9.2)
# Requirement already satisfied: ninja in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pennylane-lightning>=0.27->pennylane) (1.11.1)
# Requirement already satisfied: future>=0.15.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from autograd->pennylane) (0.18.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests->pennylane) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests->pennylane) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests->pennylane) (2.1.1)
# Requirement already satisfied: rustworkx==0.12.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from retworkx->pennylane) (0.12.0)
# Requirement already satisfied: noisyopt in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: scipy in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from noisyopt) (1.9.2)
# Requirement already satisfied: numpy in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from noisyopt) (1.23.1)
# Requirement already satisfied: ipympl in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: numpy in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (1.23.1)
# Requirement already satisfied: traitlets<6 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: ipython-genutils in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: ipython<9 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipympl) (7.31.1)
# Requirement already satisfied: setuptools>=18.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (63.4.1)
# Requirement already satisfied: jedi>=0.16 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: pickleshare in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: decorator in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: pygments in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: backcall in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: nbformat>=4.2.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: nest-asyncio in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.3.5)
# Requirement already satisfied: psutil in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: jupyter_core in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: fastjsonschema in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: attrs>=17.4.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: entrypoints in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: nbconvert>=5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: argon2-cffi in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: prometheus-client in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: jinja2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.0.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: testpath in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: bleach in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: defusedxml in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.1)
# Requirement already satisfied: webencodings in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Requirement already satisfied: ibm_quantum_widgets in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ibm_quantum_widgets) (7.6.5)
# Requirement already satisfied: qiskit>=0.23.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ibm_quantum_widgets) (0.39.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (7.31.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipywidgets>=7.0.0->ibm_quantum_widgets) (5.5.0)
# Requirement already satisfied: qiskit-aer==0.11.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit>=0.23.5->ibm_quantum_widgets) (0.11.0)
# Requirement already satisfied: qiskit-terra==0.22.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit>=0.23.5->ibm_quantum_widgets) (0.22.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit>=0.23.5->ibm_quantum_widgets) (0.19.2)
# Requirement already satisfied: scipy>=1.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-aer==0.11.0->qiskit>=0.23.5->ibm_quantum_widgets) (1.9.2)
# Requirement already satisfied: numpy>=1.16.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-aer==0.11.0->qiskit>=0.23.5->ibm_quantum_widgets) (1.23.1)
# Requirement already satisfied: websockets>=10.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (10.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (2.8.2)
# Requirement already satisfied: requests>=2.19 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (2.28.1)
# Requirement already satisfied: urllib3>=1.21.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.26.12)
# Requirement already satisfied: websocket-client>=1.0.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.4.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (1.1.1)
# Requirement already satisfied: stevedore>=3.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (4.0.1)
# Requirement already satisfied: sympy>=1.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (1.11.1)
# Requirement already satisfied: retworkx>=0.11.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (0.12.0)
# Requirement already satisfied: psutil>=5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (5.9.2)
# Requirement already satisfied: dill>=0.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (0.3.5.1)
# Requirement already satisfied: symengine>=0.9 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (0.9.2)
# Requirement already satisfied: ply>=3.10 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (3.11)
# Requirement already satisfied: tornado>=6.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (6.2)
# Requirement already satisfied: pyzmq>=17 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (23.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (1.5.1)
# Requirement already satisfied: nest-asyncio in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (1.5.5)
# Requirement already satisfied: packaging in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (21.3)
# Requirement already satisfied: decorator in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.18.1)
# Requirement already satisfied: backcall in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (63.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (3.0.20)
# Requirement already satisfied: pygments in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (4.8.0)
# Requirement already satisfied: jupyter_core in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (4.16.0)
# Requirement already satisfied: fastjsonschema in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (2.16.2)
# Requirement already satisfied: notebook>=4.4.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (6.4.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.18.0)
# Requirement already satisfied: entrypoints in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.4)
# Requirement already satisfied: argon2-cffi in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (6.4.4)
# Requirement already satisfied: prometheus-client in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.13.1)
# Requirement already satisfied: jinja2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (2022.9.24)
# Requirement already satisfied: cryptography>=1.3 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (38.0.1)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.5.0)
# Requirement already satisfied: rustworkx==0.12.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from retworkx>=0.11.0->qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (0.12.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (5.10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from sympy>=1.3->qiskit-terra==0.22.0->qiskit>=0.23.5->ibm_quantum_widgets) (1.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm_quantum_widgets) (3.0.9)
# Requirement already satisfied: cffi>=1.12 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (1.15.1)
# Requirement already satisfied: beautifulsoup4 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (4.11.1)
# Requirement already satisfied: bleach in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (4.1.0)
# Requirement already satisfied: testpath in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (1.5.0)
# Requirement already satisfied: defusedxml in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (2.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (21.2.0)
# Requirement already satisfied: pycparser in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm_quantum_widgets) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (2.3.1)
# Requirement already satisfied: webencodings in /home/david/anaconda3/envs/App_q_comp/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->ibm_quantum_widgets) (0.5.1)

# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

from pennylane import qchem
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
from noisyopt import minimizeSPSA
import time

# Loading your IBM Quantum account(s)
# provider = IBMQ.load_account()

# %%
# The number of iterations of the optimizer
niter_spsa = 200

# The true energy of the H2 molecule
true_energy = -1.136189454088

# Seed number, for reproducibility of random initialization
seednum=0

# Optimizer hyperparameters
# TODO : search the documentation of minimizeSPSA to see
# what they mean and are used for.
c_value=0.3
a_value=1.5

# Setup the data of the molecule to optimize for
symbols = ["H", "H"]
coordinates = np.array([0.0, 0.0, -0.6614, 0.0, 0.0, 0.6614])

# TODO: You need a function from quantum chemistry (qchem) that,
# using the symbols and chemistry coordinates of the H2 molecule,
# gives you the corresponding hamiltonian
h2_ham, num_qubits = qchem.molecular_hamiltonian(symbols, coordinates)

# Variational ansatz for H2 
def circuit(params, wires): 
    qml.BasisState(np.array([1, 1, 0, 0]), wires=wires)
    for i in wires:
        qml.Rot(*params[i], wires=i)
            
    # TODO: add 3 controlled-NOT gates for entanglement, 
    # where the control - target pairs are [(2, 3), (2, 0), (3, 1)]
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[2, 0])
    qml.CNOT(wires=[3, 1])

num_params=3 

# TODO : find the name of the pennylane qubit device (the default one)
devicename= 

# TODO: how do you instantiate a quantum device on pennylane?
# You should find a function that uses the devicename and number of 
# qubits, also known as wires
dev =  

def exp_val_circuit(params):
    circuit(params, range(dev.num_wires))
    # TODO: measure and return the expectation value of the circuit
    # with respect to the Hamiltonian of the H2 circuit measured above
    return 

# Pennylane uses Quantum Nodes (Qnodes)
# TODO: create a QNode corresponding to the
# last circuit defined above and that acts on the device we created
cost_spsa = 

# Wrapping the cost function and flattening the parameters to be compatible with noisyopt which assumes a flat array of input parameters
def wrapped_cost(params):  
    return cost_spsa(params.reshape(num_qubits, num_params))


## Here we define the callback function that is used by the SPSA optimizer
def callback_fn(xk):
    cost_val = wrapped_cost(xk)
    h2_spsa_energies.append(cost_val)
    
    # We have evaluated every term twice, so we need to make up for this
    num_executions = int(dev.num_executions / 2) 
    h2_spsa_device_executions.append(num_executions)
    h2_spsa_params.append(xk)


results=[]

## Set initial rotation parameters
np.random.seed(seednum)
init_params = np.random.normal(0, np.pi, (num_qubits, 3), requires_grad=True)
initial_name='random seed '+str(seednum)
params = init_params.copy().reshape(num_qubits * num_params) #flatten

h2_spsa_device_executions = [0]
h2_spsa_energies = [wrapped_cost(params)]
h2_spsa_params = []

## TO DO : add the parameters to the minimizeSPSA function
res = minimizeSPSA()

print("Result:", res)
results.append(h2_spsa_device_executions)
results.append(h2_spsa_energies)
results.append(h2_spsa_params)
print()
print(f"Final estimated value of the ground-state energy = {h2_spsa_energies [-1]:.8f} Ha")
print(
   f"Accuracy with respect to the true energy: {np.abs(h2_spsa_energies [-1] - true_energy):.8f} Ha"
)
# Out:
#   File "/tmp/ipykernel_5012/3853681035.py", line 40
#     devicename=
#                 ^
# SyntaxError: invalid syntax

# %%
## Energy vs. iteration plot
# %matplotlib ipympl 
plt.figure(figsize=(10, 6))
plt.plot(range(niter_spsa + 1), results[1], label = "Energy level of the current VQE using SPSA")
plt.title("H2 energy from the VQE using SPSA using "+ devicename, fontsize=16)
plt.xlabel("Number of optimization iterations", fontsize=14)
plt.ylabel("Energy (Ha)", fontsize=14)
plt.grid()
plt.hlines(true_energy, 0, niter_spsa+2, label="True energy level of H2", color = "red")
plt.legend(fontsize=14)
plt.show()
